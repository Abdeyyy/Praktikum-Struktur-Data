# %%
#LINEAR PROBING - MODIFIKASI

class Lp:
  def __init__(self, size):
    self.size = size
    self.table = [None] * size

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key, value):
    index = self.hash_function(key)
    original_index = index

    while self.table[index] is not None:
      if self.table[index][0] == key:
        break
      index = (index+1) % self.size
      if index == original_index:
        raise Exception('Hash table penuh')
    self.table[index] = (key, value)

  def search(self, key):
    index = self.hash_function(key)
    original_index = index

    while self.table[index] is not None:
      if self.table[index][0] == key:
        return self.table[index][1]
      index = (index+1) % self.size
      if index == original_index:
        break
    return None

  #tambahan fungsi untuk menampilkan self.table
  def show(self):
    return self.table

ht = Lp(5)
ht.insert('A', 10)
ht.insert('B', 20)
ht.insert('C', 30)
ht.insert('D', 40)
ht.insert('E', 50)
print(ht.show())

#mengecek nilai hash tiap key
cek_hash = ['A','B','C','D','E']
for i in cek_hash:
  print(f'Nilai hash {i} :',hash(i) % 5)
# Out:
# [('A', 10), ('C', 30), ('E', 50), ('D', 40), ('B', 20)]
# Nilai hash A : 0
# Nilai hash B : 4
# Nilai hash C : 4
# Nilai hash D : 3
# Nilai hash E : 0

# %%
#CHAINING - MODIFIKASI

class Chaining:
  def __init__(self, size):
    self.size = size
    self.table = [[] for _ in range(size)]

  def hash_function(self, key):
    return hash(key) % self.size

  def insert(self, key,value):
    index = self.hash_function(key)
    for i, (k,v) in enumerate(self.table[index]):
      if k == key:
        self.table[index][i] = (key, value)
        return
    self.table[index].append((key,value))

  def search(self, key):
    index = self.hash_function(key)
    for k, v in self.table[index]:
      if k == key:
        return v
    return None

  #tambahan fungsi untuk menampilkan self.table
  def show(self):
    return self.table

ht = Chaining(3)
ht.insert('apel', 100)
ht.insert('melon', 200)
ht.insert('lemon', 300)
ht.insert('pisang', 400)

print(ht.show())

cek_hash = ['apel','melon','lemon','pisang']
for i in cek_hash:
  print(f'Nilai hash {i} :',hash(i) % 3)
# Out:
# [[('lemon', 300), ('pisang', 400)], [('apel', 100), ('melon', 200)], []]
# Nilai hash apel : 1
# Nilai hash melon : 1
# Nilai hash lemon : 0
# Nilai hash pisang : 0
