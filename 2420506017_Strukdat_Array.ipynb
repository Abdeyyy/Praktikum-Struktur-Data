# %%
#LATIHAN 1
npm = [2410506013, 2410506014, 2410506015, 2410506016, 2420506017]
n=13

for i in npm:
  print(f'NPM ke {n} :',i)
  n=n+1
# Out:
# NPM ke 13 : 2410506013
# NPM ke 14 : 2410506014
# NPM ke 15 : 2410506015
# NPM ke 16 : 2410506016
# NPM ke 17 : 2420506017

# %%
#LATIHAN 2
angka=[100, 60]
angka.append(17)
angka.pop(0)

print(angka)
# Out:
# [60, 17]

# %%
#LATIHAN 3
fakultas = ['Teknik','Pertanian','Keguruan dan Ilmu Pendidikan','Ekonomi','Ilmu Sosial dan Politik']

print('Ada 5 fakultas di Untidar, yaitu :\n')
n=1
for i in fakultas:
  print(f'{n}. Fakultas',i)
  n+=1
# Out:
# Ada 5 fakultas di Untidar, yaitu :
#
# 1. Fakultas Teknik
# 2. Fakultas Pertanian
# 3. Fakultas Keguruan dan Ilmu Pendidikan
# 4. Fakultas Ekonomi
# 5. Fakultas Ilmu Sosial dan Politik

# %%
#LATIHAN 4
harga = [20000, 14000, 30000, 40000]
print('Jumlah elemen di array harga adalah', len(harga))
# Out:
# Jumlah elemen di array harga adalah 4

# %%
#LATIHAN 5
matriks = [
    [1,2,3,4],
    [4,5,6,7],
    [8,9,1,1]
]

for i in matriks:
  print(i)
# Out:
# [1, 2, 3, 4]
# [4, 5, 6, 7]
# [8, 9, 1, 1]

# %%
#LATIHAN 6
matriks = [
    [1,2,3,4],
    [4,5,6,7],
    [8,9,1,1]
]

print('Elemen pada baris 2, kolom 4 adalah :', matriks[1][3])
# Out:
# Elemen pada baris 2, kolom 4 adalah : 7

# %%
#LATIHAN 7
matriks = [
    [1,2,3,4],
    [4,5,6,7],
    [8,9,1,1]
]
matriks.append([1,1,20,6])

for i in matriks:
  print(i)
# Out:
# [1, 2, 3, 4]
# [4, 5, 6, 7]
# [8, 9, 1, 1]
# [1, 1, 20, 6]

# %%
#LATIHAN 8
matriks = [
    [1,2,3,4],
    [4,5,6,7],
    [8,9,1,1]
]
matriks.append([1,1,20,6])
matriks[3].remove(20)

for i in matriks:
  print(i)
# Out:
# [1, 2, 3, 4]
# [4, 5, 6, 7]
# [8, 9, 1, 1]
# [1, 1, 6]

# %%
#LATIHAN 9
matriks = [
    [1,2,3,4],
    [4,5,6,7],
    [8,9,1,1]
]
matriks.append([1,1,20,6])
matriks[3][0]=14
matriks[3][1]=2
matriks[3][2]=20
matriks[3][3]=25

for i in matriks:
  print(i)
# Out:
# [1, 2, 3, 4]
# [4, 5, 6, 7]
# [8, 9, 1, 1]
# [14, 2, 20, 25]

# %%
#LATIHAN 10
belanja = ['Sabun','Shampo','Sikat gigi','Es teh']
belanja.append('Pasta gigi')
belanja.pop(3)

print('Belanja hari ini :',belanja)
# Out:
# Belanja hari ini : ['Sabun', 'Shampo', 'Sikat gigi', 'Pasta gigi']
